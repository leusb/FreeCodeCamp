# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("medical_examination.csv")

# %%
df.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349843    164.359229     74.205690
# std    28851.302323   2467.251667      0.477253      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      3.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
df.shape
# Out:
# (70000, 13)

# %%
df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
df["height"]/100
# Out:
# 0        1.68
# 1        1.56
# 2        1.65
# 3        1.69
# 4        1.56
#          ...
# 69995    1.68
# 69996    1.58
# 69997    1.83
# 69998    1.63
# 69999    1.70
# Name: height, Length: 70000, dtype: float64

# %%
BMI = df["weight"]/(((df["height"])/100)**2)

# %%
BMI.astype(int)
# Out:
# 0        21
# 1        34
# 2        23
# 3        28
# 4        23
#          ..
# 69995    26
# 69996    50
# 69997    31
# 69998    27
# 69999    24
# Length: 70000, dtype: int64

# %%
type(BMI)
# Out:
# pandas.core.series.Series

# %%
df["overweight"]= np.where(BMI >25, 1 ,0)

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 1          0  18393       2     168    62.0    110     80            0     0
# 2          1  20228       1     156    85.0    140     90            1     0
# 3          2  18857       1     165    64.0    130     70            1     0
# 4          3  17623       2     169    82.0    150    100            0     0
# 5          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69996  99993  19240       2     168    76.0    120     80            0     0
# 69997  99995  22601       1     158   126.0    140     90            1     1
# 69998  99996  19066       2     183   105.0    180     90            1     0
# 69999  99998  22431       1     163    72.0    135     80            0     1
# 70000  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
df["gluc"]= np.where(df["gluc"]<=1, 0 ,1)

# %%
df["cholesterol"]= np.where(df["cholesterol"]<=1, 0 ,1)

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69997  99996  19066       2     183   105.0    180     90            1     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
df.index = np.arange(1, len(df)+1)

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 1          0  18393       2     168    62.0    110     80            0     0
# 2          1  20228       1     156    85.0    140     90            1     0
# 3          2  18857       1     165    64.0    130     70            1     0
# 4          3  17623       2     169    82.0    150    100            0     0
# 5          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69996  99993  19240       2     168    76.0    120     80            0     0
# 69997  99995  22601       1     158   126.0    140     90            1     1
# 69998  99996  19066       2     183   105.0    180     90            1     0
# 69999  99998  22431       1     163    72.0    135     80            0     1
# 70000  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
df_cat = pd.melt(df, id_vars = 'cardio', var_name = 'variable', value_vars = ['alco', 'active','cholesterol', 'gluc', 'overweight','smoke'])

# %%
df_cat
# Out:
#         cardio variable  value
# 0            0   active      1
# 1            1   active      1
# 2            1   active      0
# 3            1   active      1
# 4            0   active      0
# ...        ...      ...    ...
# 349995       0    smoke      1
# 349996       1    smoke      0
# 349997       1    smoke      0
# 349998       1    smoke      0
# 349999       0    smoke      0
#
# [350000 rows x 3 columns]

# %%
df_cat = pd.melt(df,id_vars = 'cardio', var_name = 'variable', value_vars = ['active','cholesterol', 'gluc','overweight','smoke'])

# %%
fig = sns.catplot(data=df_cat, kind="count",  x="variable",hue="value", col="cardio").set_axis_labels("variable", "total")
fig = fig.fig

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 1          0  18393       2     168    62.0    110     80            0     0
# 2          1  20228       1     156    85.0    140     90            1     0
# 3          2  18857       1     165    64.0    130     70            1     0
# 4          3  17623       2     169    82.0    150    100            0     0
# 5          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69996  99993  19240       2     168    76.0    120     80            0     0
# 69997  99995  22601       1     158   126.0    140     90            1     1
# 69998  99996  19066       2     183   105.0    180     90            1     0
# 69999  99998  22431       1     163    72.0    135     80            0     1
# 70000  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
df_heat = df[(df['ap_lo']<=df['ap_hi']) &
    (df['height'] >= df['height'].quantile(0.025))&
    (df['height'] <= df['height'].quantile(0.975))&
    (df['weight'] >= df['weight'].quantile(0.025))&
    (df['weight'] <= df['weight'].quantile(0.975))
    ]

# %%
corr = df_heat.corr()
corr
# Out:
#                    id       age    gender    height    weight     ap_hi  \
# id           1.000000  0.002507  0.003426  0.000326  0.000149  0.003492
# age          0.002507  1.000000 -0.018132 -0.076932  0.070168  0.018689
# gender       0.003426 -0.018132  1.000000  0.505785  0.129979  0.005063
# height       0.000326 -0.076932  0.505785  1.000000  0.251503  0.004586
# weight       0.000149  0.070168  0.129979  0.251503  1.000000  0.027030
# ap_hi        0.003492  0.018689  0.005063  0.004586  0.027030  1.000000
# ap_lo        0.000484  0.153508  0.059947  0.017922  0.227922  0.072803
# cholesterol  0.003719  0.129996 -0.037605 -0.063522  0.135981  0.022807
# gluc         0.002289  0.086990 -0.021357 -0.030469  0.107072  0.011111
# smoke       -0.002732 -0.044371  0.337436  0.187830  0.056533 -0.001928
# alco        -0.000708 -0.026970  0.168637  0.089785  0.059917  0.000769
# active       0.005891 -0.011445  0.007864 -0.005661 -0.014430 -0.000222
# ...

# %%
mask = np.triu(corr)

# %%
mask
# Out:
# array([[ 1.00000000e+00,  2.50729691e-03,  3.42610273e-03,
#          3.25916709e-04,  1.49333224e-04,  3.49238023e-03,
#          4.83670793e-04,  3.71939143e-03,  2.28909034e-03,
#         -2.73227725e-03, -7.08059804e-04,  5.89114223e-03,
#          3.90011059e-03, -8.62780452e-04],
#        [ 0.00000000e+00,  1.00000000e+00, -1.81320052e-02,
#         -7.69318347e-02,  7.01683896e-02,  1.86894095e-02,
#          1.53507973e-01,  1.29996176e-01,  8.69901449e-02,
#         -4.43706471e-02, -2.69695382e-02, -1.14451266e-02,
#          2.40241089e-01,  9.62642736e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          5.05784851e-01,  1.29979320e-01,  5.06250408e-03,
#          5.99466484e-02, -3.76050443e-02, -2.13573847e-02,
#          3.37435881e-01,  1.68637124e-01,  7.86370242e-03,
#          2.31999158e-03, -7.36697306e-02],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00,  2.51502865e-01,  4.58573625e-03,
# ...
