# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("adult.data.csv")

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
c=df.groupby('salary')

# %%
edu.max()dd
# Out:
#               age    workclass   fnlwgt  education-num marital-status  \
# education
# 10th           90    State-gov   766115              6        Widowed
# 11th           90    State-gov   806316              7        Widowed
# 12th           79    State-gov   917220              8        Widowed
# 1st-4th        90    State-gov   795830              2        Widowed
# 5th-6th        84    State-gov   684015              3        Widowed
# 7th-8th        90  Without-pay   750972              4        Widowed
# 9th            90    State-gov   758700              5        Widowed
# Assoc-acdm     90  Without-pay  1455435             12        Widowed
# Assoc-voc      84    State-gov  1366120             11        Widowed
# Bachelors      90    State-gov  1226583             13        Widowed
# Doctorate      80    State-gov   606111             16        Widowed
# HS-grad        90  Without-pay  1268339              9        Widowed
# ...

# %%
c.max()
# Out:
#         age    workclass   fnlwgt     education  education-num marital-status  \
# salary
# <=50K    90  Without-pay  1484705  Some-college             16        Widowed
# >50K     90    State-gov  1226583  Some-college             16        Widowed
#
#               occupation relationship   race   sex  capital-gain  \
# salary
# <=50K   Transport-moving         Wife  White  Male         41310
# >50K    Transport-moving         Wife  White  Male         99999
#
#         capital-loss  hours-per-week native-country
# salary
# <=50K           4356              99     Yugoslavia
# >50K            3683              99     Yugoslavia
